# %% [markdown]
# # Experiment 03 — Data Handling with Python

# %% [markdown]
# ## Aim
# To understand and perform data handling using Python libraries (NumPy and Pandas) for preprocessing datasets in Machine Learning.

# %% [markdown]
# ## Dataset
# - **Name:** Titanic — Machine Learning from Disaster
# - **File:** `titanic_train.csv`
# - **Source:** https://www.kaggle.com/competitions/titanic/data

# %% [markdown]
# ## Theory
#
# ### Data Handling in ML
# Data handling involves loading, cleaning, transforming, and analyzing data before feeding it into a machine learning model.
#
# **Libraries used:**
# - **NumPy:** Efficient handling of numerical arrays and matrices.
# - **Pandas:** Provides Series and DataFrame for tabular data handling.
# - **Matplotlib / Seaborn:** Visualization for exploratory data analysis.
#
# **Common Operations:**
# - Loading data: `pd.read_csv()`, `pd.read_excel()`
# - Exploring data: `.head()`, `.info()`, `.describe()`
# - Cleaning data: Handling null values, duplicates, and inconsistent formats
# - Transformation: Feature scaling, encoding categorical data
# - Aggregation: Grouping and summarizing data
# - Visualization: Understanding data distributions and relationships

# %% [markdown]
# ## Procedure / Implementation

# %% [markdown]
# ### Step 1 — Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2 — Load the dataset

# %%
df = pd.read_csv('titanic_train.csv')
print(df.head())
print('\nShape:', df.shape)
print('\nInfo:')
df.info()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %% [markdown]
# ### Step 3 — Check and clean the data

# %%
print('Missing values:\n', df.isnull().sum())

df['Age'] = df['Age'].fillna(df['Age'].median())
df = df.drop_duplicates()
print('\nAfter cleaning — missing Age:', df['Age'].isnull().sum())
# Out:
# Missing values:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# After cleaning — missing Age: 0

# %% [markdown]
# ### Step 4 — Transform the data

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
print(df[['Age', 'Sex', 'FamilySize']].head())
# Out:
#     Age  Sex  FamilySize
# 0  22.0    0           2
# 1  38.0    1           2
# 2  26.0    1           1
# 3  35.0    1           2
# 4  35.0    0           1

# %% [markdown]
# ### Step 5 — Basic analysis and visualization

# %%
print('Mean Age:', df['Age'].mean())
print('Median Age:', df['Age'].median())

sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

sns.countplot(x='Sex', data=df)
plt.title('Gender Count')
plt.show()
# Out:
# Mean Age: 29.36158249158249
# Median Age: 28.0

# %% [markdown]
# ### Step 6 — Save the cleaned data

# %%
df.to_csv('cleaned_titanic.csv', index=False)
print('Cleaned dataset saved as cleaned_titanic.csv')
# Out:
# Cleaned dataset saved as cleaned_titanic.csv

# %% [markdown]
# ## Output / Observations
# - Displayed initial dataset and identified missing values (Age, Cabin, Embarked).
# - Filled missing Age with median, removed duplicate rows.
# - Encoded Sex as numeric and created a FamilySize feature.
# - Histograms and count plots show data distributions.
# - Saved a clean CSV ready for ML model training.

# %% [markdown]
# ## Result / Conclusion
# Successfully performed data handling using Python libraries: loaded, cleaned, transformed, and visualized the dataset, preparing it for machine learning model development.
#
# **CO Achieved:** CO2
# - Apply data cleaning, transformation, and visualization techniques.
# - Demonstrate pre-processing steps essential for training accurate models.
#
# **POs Achieved:**
# - PO1: Apply foundational programming to handle datasets.
# - PO2: Analyze data quality and handle missing or noisy data.
# - PO3 (Design Solutions): Design efficient workflows for preparing data.
# - PO4: Conduct experiments on datasets to validate results.
# - PO5: Utilize libraries like Pandas/NumPy for modern data handling.
#
# **PSO Achieved:**
# - PSO1: Enhance ML workflows through data handling skills.
# - PSO2: Integrate data cleaning into scalable analytics pipelines.
